# %%
pip install pydataset
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from pydataset import data
# Out:
# initiated datasets repo at: /Users/guadalupeluna/.pydataset/

# %%
import pandas as pd
import numpy as np

# %%
# All the datasets loaded from the pydataset library will be 
# pandas dataframes.

# %%
# 1. Copy the code from the lesson to create a dataframe 
# full of student grades.

# %%
np.random.seed(123)

students = ['Sally', 'Jane', 'Suzie', 'Billy', 'Ada', 'John', 'Thomas',
            'Marie', 'Albert', 'Richard', 'Isaac', 'Alan']

# randomly generate scores for each student for each subject
# note that all the values need to have the same length here
math_grades = np.random.randint(low=60, high=100, size=len(students))
english_grades = np.random.randint(low=60, high=100, size=len(students))
reading_grades = np.random.randint(low=60, high=100, size=len(students))

df = pd.DataFrame({'name': students,
                   'math': math_grades,
                   'english': english_grades,
                   'reading': reading_grades})

type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#        name  math  english  reading
# 0     Sally    62       85       80
# 1      Jane    88       79       67
# 2     Suzie    94       74       95
# 3     Billy    98       96       88
# 4       Ada    77       92       98
# 5      John    79       76       93
# 6    Thomas    82       64       81
# 7     Marie    93       63       90
# 8    Albert    92       62       87
# 9   Richard    69       80       94
# 10    Isaac    92       99       93
# 11     Alan    92       62       72

# %%
# a. Create a column named passing_english that indicates 
# whether each student has a passing grade in english.

# %%
df['passing_english'] = df.english > 70

# %%
df
# Out:
#        name  math  english  reading  passing_english
# 0     Sally    62       85       80             True
# 1      Jane    88       79       67             True
# 2     Suzie    94       74       95             True
# 3     Billy    98       96       88             True
# 4       Ada    77       92       98             True
# 5      John    79       76       93             True
# 6    Thomas    82       64       81            False
# 7     Marie    93       63       90            False
# 8    Albert    92       62       87            False
# 9   Richard    69       80       94             True
# 10    Isaac    92       99       93             True
# 11     Alan    92       62       72            False

# %%
# b. Sort the english grades by the passing_english column. How are duplicates handled?

# %%
df.sort_values(by='passing_english')
# Out:
#        name  math  english  reading  passing_english
# 6    Thomas    82       64       81            False
# 7     Marie    93       63       90            False
# 8    Albert    92       62       87            False
# 11     Alan    92       62       72            False
# 0     Sally    62       85       80             True
# 1      Jane    88       79       67             True
# 2     Suzie    94       74       95             True
# 3     Billy    98       96       88             True
# 4       Ada    77       92       98             True
# 5      John    79       76       93             True
# 9   Richard    69       80       94             True
# 10    Isaac    92       99       93             True

# %%
# c. Sort the english grades first by passing_english and then by student name. All the students 
# that are failing english should be first, and within the students that are failing english they 
# should be ordered alphabetically. The same should be true for the students passing english. 
# (Hint: you can pass a list to the .sort_values method)

# %%
df.sort_values(by=['passing_english', 'name'], ascending = [True, True])
# Out:
#        name  math  english  reading  passing_english
# 11     Alan    92       62       72            False
# 8    Albert    92       62       87            False
# 7     Marie    93       63       90            False
# 6    Thomas    82       64       81            False
# 4       Ada    77       92       98             True
# 3     Billy    98       96       88             True
# 10    Isaac    92       99       93             True
# 1      Jane    88       79       67             True
# 5      John    79       76       93             True
# 9   Richard    69       80       94             True
# 0     Sally    62       85       80             True
# 2     Suzie    94       74       95             True

# %%
# d. Sort the english grades first by passing_english, and then by the actual english grade, 
# similar to how we did in the last step.

# %%
df.sort_values(by=['passing_english', 'english'], ascending = [False, False])
# Out:
#        name  math  english  reading  passing_english
# 10    Isaac    92       99       93             True
# 3     Billy    98       96       88             True
# 4       Ada    77       92       98             True
# 0     Sally    62       85       80             True
# 9   Richard    69       80       94             True
# 1      Jane    88       79       67             True
# 5      John    79       76       93             True
# 2     Suzie    94       74       95             True
# 6    Thomas    82       64       81            False
# 7     Marie    93       63       90            False
# 8    Albert    92       62       87            False
# 11     Alan    92       62       72            False

# %%
# e. Calculate each students overall grade and add it as a column on the dataframe. The overall grade 
# is the average of the math, english, and reading grades.

# %%
df['overall_grade'] = (df.math + df.english + df.reading) / 3
df
# Out:
#        name  math  english  reading  passing_english  overall_grade
# 0     Sally    62       85       80             True      75.666667
# 1      Jane    88       79       67             True      78.000000
# 2     Suzie    94       74       95             True      87.666667
# 3     Billy    98       96       88             True      94.000000
# 4       Ada    77       92       98             True      89.000000
# 5      John    79       76       93             True      82.666667
# 6    Thomas    82       64       81            False      75.666667
# 7     Marie    93       63       90            False      82.000000
# 8    Albert    92       62       87            False      80.333333
# 9   Richard    69       80       94             True      81.000000
# 10    Isaac    92       99       93             True      94.666667
# 11     Alan    92       62       72            False      75.333333

# %%
# 2. Load the mpg dataset. Read the documentation for the dataset and use it for the following questions:

# %%
mpg = data('mpg')
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# ...

# %%
# - How many rows and columns are there?

# %%
mpg.shape
# Out:
# (234, 12)

# %%
# - What are the data types of each column?

# %%
mpg.dtypes
# Out:
# manufacturer     object
# model            object
# displ           float64
# year              int64
# cyl               int64
# trans            object
# drv              object
# cty               int64
# hwy               int64
# fl               object
# class            object
# dtype: object

# %%
# - Summarize the dataframe with .info and .describe

# %%
mpg.info
# Out:
# <bound method DataFrame.info of     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ...

# %%
mpg.describe
# Out:
# <bound method NDFrame.describe of     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# ...

# %%
# - Rename the cty column to city

# %%
mpg.rename(columns={'cty': 'city'}, inplace=True)
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
# ...

# %%
# - Rename the hwy column to highway

# %%
mpg.rename(columns={'hwy': 'highway'}, inplace = True)
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
# ...

# %%
# - Do any cars have better city mileage than highway mileage?

# %%
mpg[mpg.cty > mpg.hwy]
# left blank rows and columns because there were none
# Out:
# Empty DataFrame
# Columns: [manufacturer, model, displ, year, cyl, trans, drv, cty, hwy, fl, class, mileage_difference]
# Index: []

# %%
# - Create a column named mileage_difference this column should contain the difference between 
# highway and city mileage for each car.

# %%
mpg['mileage_difference'] = (mpg.hwy - mpg.cty)
mpg
# df['passing_english'] = df.english > 70
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class  mileage_difference
# 1    compact                  11
# 2    compact                   8
# ...

# %%
# - Which car (or cars) has the highest mileage difference?

# %%
mpg.sort_values(by='mileage_difference', ascending = False).head(2)
# Out:
#     manufacturer       model  displ  year  cyl     trans drv  cty  hwy fl  \
# 107        honda       civic    1.8  2008    4  auto(l5)   f   24   36  c
# 223   volkswagen  new beetle    1.9  1999    4  auto(l4)   f   29   41  d
#
#           class  mileage_difference  average_mileage
# 107  subcompact                  12             30.0
# 223  subcompact                  12             35.0

# %%
# - Which compact class car has the lowest highway mileage? The best?

# %%
mpg[mpg['class'] == 'compact'].sort_values(by='hwy', ascending = True).head(1)
# filter (mask) was mpg[mpg['class'] == 'compact'].
# Out:
#     manufacturer  model  displ  year  cyl     trans drv  cty  hwy fl    class  \
# 220   volkswagen  jetta    2.8  1999    6  auto(l4)   f   16   23  r  compact
#
#      mileage_difference  average_mileage
# 220                   7             19.5

# %%
mpg[mpg['class'] == 'compact'].sort_values(by='hwy', ascending = True).tail(1)
# Out:
#     manufacturer  model  displ  year  cyl       trans drv  cty  hwy fl  \
# 213   volkswagen  jetta    1.9  1999    4  manual(m5)   f   33   44  d
#
#        class  mileage_difference  average_mileage
# 213  compact                  11             38.5

# %%
# - Create a column named average_mileage that is the mean of the city and highway mileage.

# %%
mpg['average_mileage'] = (mpg.cty + mpg.hwy) / 2
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class  mileage_difference  average_mileage
# 1    compact                  11             23.5
# ...

# %%
# - Which dodge car has the best average mileage? The worst?

# %%
mpg[mpg['manufacturer'] == 'dodge'].sort_values(by = 'average_mileage', ascending = False).head(1)
# Out:
#    manufacturer        model  displ  year  cyl     trans drv  cty  hwy fl  \
# 38        dodge  caravan 2wd    2.4  1999    4  auto(l3)   f   18   24  r
#
#       class  mileage_difference  average_mileage
# 38  minivan                   6             21.0

# %%
mpg[mpg['manufacturer'] == 'dodge'].sort_values(by = 'average_mileage', ascending = False).tail(4)
# Out:
#    manufacturer                model  displ  year  cyl       trans drv  cty  \
# 66        dodge  ram 1500 pickup 4wd    4.7  2008    8    auto(l5)   4    9
# 60        dodge          durango 4wd    4.7  2008    8    auto(l5)   4    9
# 55        dodge    dakota pickup 4wd    4.7  2008    8    auto(l5)   4    9
# 70        dodge  ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4    9
#
#     hwy fl   class  mileage_difference  average_mileage
# 66   12  e  pickup                   3             10.5
# 60   12  e     suv                   3             10.5
# 55   12  e  pickup                   3             10.5
# 70   12  e  pickup                   3             10.5

# %%
# 3. Load the Mammals dataset. Read the documentation for it, and use the data to answer these questions:

# %%
Mammals = data('Mammals')
Mammals
# Out:
#        weight  speed  hoppers  specials
# 1    6000.000   35.0    False     False
# 2    4000.000   26.0    False     False
# 3    3000.000   25.0    False     False
# 4    1400.000   45.0    False     False
# 5     400.000   70.0    False     False
# 6     350.000   70.0    False     False
# 7     300.000   64.0    False     False
# 8     260.000   70.0    False     False
# 9     250.000   40.0    False     False
# 10   3800.000   25.0    False      True
# 11   1000.000   60.0    False     False
# 12    900.000   70.0    False     False
# 13    900.000   56.0    False     False
# 14    800.000   29.0    False     False
# 15    750.000   57.0    False     False
# 16    500.000   32.0    False     False
# 17    450.000   56.0    False     False
# 18    300.000   72.0    False     False
# 19    300.000   90.0    False     False
# 20    250.000   80.0    False     False
# 21    250.000   56.0    False     False
# 22    170.000   80.0    False     False
# ...

# %%
# - How many rows and columns are there?

# %%
Mammals.shape
# 107 rows, 4 columns
# Out:
# (107, 4)

# %%
# - What are the data types?

# %%
Mammals.dtypes
# Out:
# weight      float64
# speed       float64
# hoppers        bool
# specials       bool
# dtype: object

# %%
# - Summarize the dataframe with .info and .describe

# %%
Mammals.info
# Out:
# <bound method DataFrame.info of        weight  speed  hoppers  specials
# 1    6000.000   35.0    False     False
# 2    4000.000   26.0    False     False
# 3    3000.000   25.0    False     False
# 4    1400.000   45.0    False     False
# 5     400.000   70.0    False     False
# 6     350.000   70.0    False     False
# 7     300.000   64.0    False     False
# 8     260.000   70.0    False     False
# 9     250.000   40.0    False     False
# 10   3800.000   25.0    False      True
# 11   1000.000   60.0    False     False
# 12    900.000   70.0    False     False
# 13    900.000   56.0    False     False
# 14    800.000   29.0    False     False
# 15    750.000   57.0    False     False
# 16    500.000   32.0    False     False
# 17    450.000   56.0    False     False
# 18    300.000   72.0    False     False
# 19    300.000   90.0    False     False
# 20    250.000   80.0    False     False
# 21    250.000   56.0    False     False
# 22    170.000   80.0    False     False
# ...

# %%
Mammals.describe
# Out:
# <bound method NDFrame.describe of        weight  speed  hoppers  specials
# 1    6000.000   35.0    False     False
# 2    4000.000   26.0    False     False
# 3    3000.000   25.0    False     False
# 4    1400.000   45.0    False     False
# 5     400.000   70.0    False     False
# 6     350.000   70.0    False     False
# 7     300.000   64.0    False     False
# 8     260.000   70.0    False     False
# 9     250.000   40.0    False     False
# 10   3800.000   25.0    False      True
# 11   1000.000   60.0    False     False
# 12    900.000   70.0    False     False
# 13    900.000   56.0    False     False
# 14    800.000   29.0    False     False
# 15    750.000   57.0    False     False
# 16    500.000   32.0    False     False
# 17    450.000   56.0    False     False
# 18    300.000   72.0    False     False
# 19    300.000   90.0    False     False
# 20    250.000   80.0    False     False
# 21    250.000   56.0    False     False
# 22    170.000   80.0    False     False
# ...

# %%
# - What is the the weight of the fastest animal?

# %%
# Mammals.sort_values(by='speed', ascending = False).head(1)
Mammals[Mammals['speed'] == Mammals['speed'].max()]
# mpg.sort_values(by='mileage_difference', ascending = False).head(2)
# mpg[mpg['manufacturer'] == 'dodge'].sort_values(by = 'average_mileage', ascending = False).tail(4)
# Out:
#     weight  speed  hoppers  specials
# 53    55.0  110.0    False     False

# %%
# - What is the overal percentage of specials?

# %%
len_specials = len(Mammals[Mammals['specials'] == True])
len_specials
# Out:
# 10

# %%
(len_specials/len(Mammals['specials']))*100
# len_specials/len(Mammals['specials']) - gives the .093451111111
# Out:
# 9.345794392523365

# %%
# - How many animals are hoppers that are above the median speed? What percentage is this?

# %%
len(Mammals[Mammals['hoppers'] == True])
# Out:
# 11

# %%
speed_col = Mammals['speed']
speed_col
# Out:
# 1       35.0
# 2       26.0
# 3       25.0
# 4       45.0
# 5       70.0
# 6       70.0
# 7       64.0
# 8       70.0
# 9       40.0
# 10      25.0
# 11      60.0
# 12      70.0
# 13      56.0
# 14      29.0
# 15      57.0
# 16      32.0
# 17      56.0
# 18      72.0
# 19      90.0
# 20      80.0
# 21      56.0
# 22      80.0
# 23      48.0
# 24      70.0
# 25      80.0
# 26      61.0
# 27      33.0
# 28      64.0
# 29      55.0
# 30      65.0
# 31      56.0
# 32      45.0
# 33      60.0
# 34      81.0
# 35     100.0
# 36      60.0
# 37      40.0
# 38      47.0
# 39     105.0
# 40      80.0
# 41      97.0
# 42      97.0
# 43      80.0
# 44      45.0
# 45      81.0
# 46      40.0
# 47      48.0
# 48      56.0
# 49      59.0
# 50      48.0
# 51      65.0
# 52      60.0
# 53     110.0
# 54      50.0
# 55      64.0
# 56      67.0
# 57      70.0
# 58      65.0
# 59      24.0
# 60      30.0
# 61      56.0
# 62      60.0
# 63      72.0
# 64      64.0
# 65      27.0
# 66      16.0
# ...

# %%
median = speed_col.median()
median
# Out:
# 48.0

# %%
len_hoppers_median = Mammals[(Mammals['hoppers'] == True) & (Mammals['speed'] > median)]
len_hoppers_median
# Out:
#      weight  speed  hoppers  specials
# 96      4.6   64.0     True     False
# 97      4.4   72.0     True     False
# 98      4.0   72.0     True     False
# 99      3.5   56.0     True     False
# 100     2.0   64.0     True     False
# 101     1.9   56.0     True     False
# 102     1.5   50.0     True     False

# %%
len_mammals = len(Mammals)
len_mammals
# Out:
# 107

# %%
len(len_hoppers_median)/len_mammals
# Out:
# 0.06542056074766354
